# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Final_Project_Expense_Tracker/Final_Project_Expense_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# None

# FUNCTION DEFINITIONS
# Define sum_all
  # Return sum of all expenses

# Define sum_by_category
  # Return sum of all expenses for chosen category

# Define sum_by_vendor
  # Return sum of all expenses for chosen vendor

# PROGRAM LOGIC
# Create expenses list
expenses = []

# Create loop
while True:
  # Print menu
  print("\n--- Expense Tracker ---")
  print("1. Add New Expense")
  print("2. Print Expenses")
  print("3. Exit")

  # Prompt user
  selection = input("Selection: ")

  # If input equals 1
  if selection == "1":
    # Prompt user for category
    category = input("Enter Category: ")
    # Prompt user for vendor
    vendor = input("Enter Vendor: ")

    # Create loop
    while True:
      # Prompt user for amount
      amount_input = input("Enter Amount: ")
      # If input is valid
      try:
        # Set amount as a float
        amount = float(amount_input)
        # Break loop
        break
      # If input is invalid
      except ValueError:
        # Print error message
        print("Invalid amount. Please enter a number.")

    # Prompt user for date
    date = input("Enter Date: ")

    # Create expense directory
    expense = {
        "category": category,
        "vendor": vendor,
        "amount": amount,
        "date": date
    }

    # Add directory to expenses list
    expenses.append(expense)

  # If input equals 2
  elif selection == "2":
    # Test print
    print(expenses)

    # Print options menu

    # Prompt user for choice

    # If input equals A
      # Call sum_all function
      # Print result

    # If input equals C
      # Prompt user for category
      # Call sum_by_category function
      # Print result

    # If input equals V
      # Prompt user for vendor
      # Call sum_by_vendor function
      # Print result

    # If input is invalid
      # Print error message

  # If input equals 3
  elif selection == "3":
    # Break loop
    break

  # If input is invalid
  else:
    # Print error message
    print("Invalid selection.")
# Out:
# --- Expense Tracker ---
# 1. Add New Expense
# 2. Print Expenses
# 3. Exit
# Selection: 1
# Enter Category: Gas
# Enter Vendor: Shell
# Enter Amount: 10.50
# Enter Date: 4/10
#
# --- Expense Tracker ---
# 1. Add New Expense
# 2. Print Expenses
# 3. Exit
# Selection: 2
# [{'category': 'Gas', 'vendor': 'Shell', 'amount': 10.5, 'date': '4/10'}]
#
# --- Expense Tracker ---
# 1. Add New Expense
# 2. Print Expenses
# 3. Exit
# Selection: 1
# Enter Category: Food
# Enter Vendor: Walmart
# Enter Amount: 11.25
# Enter Date: 6/7
#
# --- Expense Tracker ---
# 1. Add New Expense
# 2. Print Expenses
# 3. Exit
# Selection: 2
# [{'category': 'Gas', 'vendor': 'Shell', 'amount': 10.5, 'date': '4/10'}, {'category': 'Food', 'vendor': 'Walmart', 'amount': 11.25, 'date': '6/7'}]
#
# --- Expense Tracker ---
# 1. Add New Expense
# 2. Print Expenses
# 3. Exit
# Selection: 3
