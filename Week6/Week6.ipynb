# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week6/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# 1. Import math

# FUNCTION DEFINITIONS
# 1. Define area(radius): returns pi * r squared
# 2. Define circumference(radius): returns 2 * pi * r
# 3. Define volume(radius, height):
#    - Call area(radius) and multiply by height.
#    - Return the result.

# PROGRAM LOGIC
# 1. Input for radius (float)
# 2. Call and print area and circumference.
# 3. Input for height (float)
# 4. Call and print volume.

import math
def area(radius):
    return math.pi * radius ** 2
def circumference(radius):
    return 2 * math.pi * radius
radius = float(input("Enter radius:"))
print("Area:", area(radius))
print("Circumference:", circumference(radius))
def volume(radius, height):
    return area(radius) * height
height = float(input("Enter height:"))
print("Cylindar Volume:", volume(radius, height))
# Out:
# Enter radius:5
# Area: 78.53981633974483
# Circumference: 31.41592653589793
# Enter height:10
# Cylindar Volume: 785.3981633974483
