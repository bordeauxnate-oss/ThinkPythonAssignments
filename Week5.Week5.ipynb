# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week5.Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
# 3. Logic: If hour < 17, subtract 2 from the price.
# 4. Print the final price.
def calculate_ticket(age, hour):
  if age <= 12 or age >= 65:
    price = 8
  else:
    price = 12
  if hour < 17:
    final_price = price - 2
  else:
    final_price = price
  print ("Your ticket price is $" + str(final_price))
# PROGRAM LOGIC
# 1. input() for age (int)
# 2. input() for movie hour (int)
# 3. Call calculate_ticket()
age = int(input("Enter age: "))
hour = int(input("Enter movie hour (0-23): "))
calculate_ticket(age, hour)
# Out:
# Enter age: 12
# Enter movie hour (0-23): 12
# Your ticket price is $6
