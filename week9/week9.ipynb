# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/week9/week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py
# IMPORT STATEMENTS
# None

# FUNCTION DEFINITIONS
# Create roster  list
# Define add_players
  # Loop until user inputs "quit"
    # Prompt the user
    # Check if player equals "quit"
      # Break loop
    # If player does not equal "quit"
      # Add player to roster
  # Return roster
# Define is_on_roster
  # Check if player name is in the roster
    # Return True
  # If player name is not in roster
    # Return Flase

# PROGRAM LOGIC
# Call add_players
# Prompt user for searched player name
# Check if player name is in roster
  # Print result
# Check if player name is not in roster
  # Print result
# Out:
# Enter player name (or 'quit' to stop) Nathan
# Enter player name (or 'quit' to stop) John
# Enter player name (or 'quit' to stop) Susan
# Enter player name (or 'quit' to stop) Debbie
# Enter player name (or 'quit' to stop) Patty
# Enter player name (or 'quit' to stop) quit
# Nathan
# John
# Susan
# Debbie
# Patty
