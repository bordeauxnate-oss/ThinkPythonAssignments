# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week12/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py
# IMPORT STATEMENTS
# None

# FUNCTION DEFINITIONS
# Define calculate_rectangle
def calculate_rectangle():
  # Calculate area
  area = length * width
  # Calculate perimeter
  perimeter = 2 * (length + width)
  # Return area and perimeter as a tuple
  return area, perimeter

# PROGRAM LOGIC
# Prompt user for length
# Prompt user for width
# Call calculate_rectangle and unpack the tuple
# Print area
# Print perimeter
# Test length
length = 10
# Test length
width = 5
# Test print
print(calculate_rectangle())
# Out:
# (50, 30)
