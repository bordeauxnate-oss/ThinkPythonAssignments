# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week8/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define is_palindrome
#   - Make the word case friendly
#   - Reverse the word
#   - Check if the word and reversed word are the same
#   - Return true if both words are the same

# PROGRAM LOGIC
# Prompt the user
# Call the function
