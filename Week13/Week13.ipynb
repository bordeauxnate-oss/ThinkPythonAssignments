# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week13/Week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: journal.py
# IMPORT STATEMENTS
# None

# FUNCTION DEFINITIONS
# Define write_entry
  # Open file in append mode
    # Write entry followed by new line

# Define read_journal
  # If file exists
    # Open file in read mode
      # Read contents
      # Print header
      # Print contents
  # If file does not exist
    # Print error message

# PROGRAM LOGIC
# Set journal filename

# Loop until user inputs "Q"
  # Prompt user

  # If prompt equals "W"
    # Prompt user for entry
    # Call write_entry
    # Print save message

  # If prompt equals "R"
    # Call read_journal

  # If prompt equals "Q"
    # Break loop

  # If prompt is invalid
    # Print error message
