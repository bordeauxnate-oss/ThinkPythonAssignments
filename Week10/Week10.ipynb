# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week10/Week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py
# IMPORT STATEMENTS
# None

# FUNCTION DEFINITIONS
# Create roster  list
roster = []
# Define add_players
def add_players():
  # Loop until user inputs "quit"
  while True:
    # Prompt the user
    player = input("Enter player name (or 'quit' to stop) ")
    # Check if player equals "quit"
    if player == "quit":
      # Break loop
      break
    # If player does not equal "quit"
    else:
      # Add player to roster
      roster.append(player)
  # Return roster
  return roster
# Define is_on_roster
def is_on_roster():
  # Check if player name is in the roster
  if searched_player in roster:
    # Return True
    return True
  # If player name is not in roster
  else:
    # Return Flase
    return False

# PROGRAM LOGIC
# Call add_players
add_players()
# Prompt user for searched player name
searched_player = input("Who would you like to search for? ")
# Check if player name is in roster
if is_on_roster() == True:
  # Print result
  print("Result: Player found!")
# Check if player name is not in roster
if is_on_roster() == False:
  # Print Result
  print("Result: Player not found.")
# Out:
# Enter player name (or 'quit' to stop) Steve
# Enter player name (or 'quit' to stop) Sasha
# Enter player name (or 'quit' to stop) quit
# Who would you like to search for? Sarah
# Result: Player not found.
