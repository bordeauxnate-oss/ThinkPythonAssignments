# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assign values to variables (name, goal, birth_year and current_year)
name = "Nathan"
goal = "I want to become an IT specialist"
birth_year = 2003
current_year = 2026
#Calculate age
age = current_year-birth_year
#Print top border line
print("="*25)
#Print bio sentences
print("My name is " + name + " and I am " + str(age) + " years old. " + goal + ".")
#Print bottom border line
print("="*25)
# Out:
# ...
# My name is Nathan and I am 23 years old. I want to become an IT specialist.
# ...
