# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week7/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
#    - Create a loop that asks for a PIN until it equals "1234"
#    - Return True
def verify_pin():
  pin = 0
  while True:
      pin = float(input("Enter your PIN: "))
      if pin == 1234:
          print("PIN Verified.")
          break
      else:
          print("Incorrect PIN. Try again.")
# 2. Define withdraw(balance, amount):
#    - Check if enough money exists
#    - Return the new (or old) balance
balance = 0
def withdraw(balance, amount):
  if amount > current_balance:
    print("Insufficient funds.")
    return current_balance
  else:
    print("Withdrawal successful.")
    return current_balance - amount
# PROGRAM LOGIC
# 1. Set current_balance to 500
current_balance = 500
# 2. Call verify_pin()
verify_pin()
# 3. Get withdrawal amount from user input
amount = float(input("Enter the amount to withdraw: "))
# 4. Update current_balance by calling withdraw()
balance = withdraw(balance, amount)
# 5. Print the final balance
print("Current Balance: $" + str(balance))
# Out:
# Enter your PIN: 0000
# Incorrect PIN. Try again.
# Enter your PIN: 1234
# PIN Verified.
# Enter the amount to withdraw: 150
# Withdrawal successful.
# Current Balance: $350.0
