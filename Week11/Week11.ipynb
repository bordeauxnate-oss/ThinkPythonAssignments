# %% [markdown]
# <a href="https://colab.research.google.com/github/bordeauxnate-oss/ThinkPythonAssignments/blob/main/Week11/Week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: gradebook.py
# IMPORT STATEMENTS
# None

# FUNCTION DEFINITIONS
# Define add_students
  # Loop until user inputs "done"
      # Prompt the user for name
      # Check if name equals "done"
        # Break loop
      # If name does not equal "done"
        # Prompt user for grade
        # Add name and grade to gradebook

# Define calculate average
  # If no names are entered
    # Return 0 to prevent divisions of 0
  # If any names have been entered
    # Calculate the sum
    # Calculate the average
  # Return average

# PROGRAM LOGIC
# Create gradebook directory
# Call add_students
# Print class report
# If no names were entered
  # Print result
# For each student in directory
  # Print student's name and grade
# Print the class average
